# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import yaml
from pprint import pprint
from collections import ChainMap

# %%
df = pd.read_stata('sec_4abcde.dta',convert_categoricals=False,columns=['hhcode','province','region','psu','itc','v1','v2','v3','v4'],iterator=True)

# %%
valubl_dict=df.value_labels()

# %%
#valubl_dict

# %%
val_list = list(valubl_dict['itc'].values())

# %%
drop_lst=[1000,1001,1002,1003,1004,1005,2000,2001,2002,2003,4000,5000,5001,5002,5003,5004,5005,5006,5007,5008,
          5009,5010,5011,6000,6001,6002,6003,6004]

# %%
df_ex = pd.read_stata('sec_4abcde.dta',convert_categoricals=False,columns=['hhcode','province','region','psu','itc','v1','v2','v3','v4'])

# %%
mask = df_ex['itc'].isin(drop_lst)
df_ex = df_ex[~mask]
df_ex.head()
# Out:
#           hhcode  province  region       psu    itc      v1  v2  v3  v4
# 25  1.102010e+09         1       2  11020101  11104  2205.0 NaN NaN NaN
# 26  1.102010e+09         1       2  11020101  11112  1000.0 NaN NaN NaN
# 27  1.102010e+09         1       2  11020101  11115   100.0 NaN NaN NaN
# 28  1.102010e+09         1       2  11020101  11117   110.0 NaN NaN NaN
# 29  1.102010e+09         1       2  11020101  11201   600.0 NaN NaN NaN

# %%
#def get_key(val):
#   for key, value in my_dict.items():
#         if val == value:
#                return key
# 
#    return "key doesn't exist"
# 
# Driver Code
# 
#my_dict = df.value_labels()['itc']
# 
#print(get_key('wheat'))

# %%
#micro_level_dict={011201:'beef fresh',011202:'beef frozen',011203:'mutton fresh',
 #                 011204:'mutton frozen',011205:'chicken farm broiler (live)',011206:'chicken meat fresh',011207:chicken meat fresh
#
 #   
#}

# %%
#print(list(valubl_dict.keys())[list(valubl_dict.values()).index(11101)])

# %%
#df.drop(df[df['itc'] == [drop_lst]].index, inplace = True)

# %%
#df.apply(lambda row: row[df['itc'].isin(drop_lst)])
#df.dropna()

# %%
val_list[2]
# Out:
# 'wheat flour avg .qlty(loose)'

# %%
pg_ttl_dict={1001:[11201,11202,11203, 11204, 11205, 11206, 11207, 11208,11301,11302,11303,
                   11401, 11402, 11403, 11404, 11405, 11406, 11407, 11408, 11409,11601,11602,11603,11604],
             1002:[11605, 11606, 11607, 11608, 11609, 11610, 11611, 11612, 11613, 11614, 11615, 11616,11701, 11702, 11703,
                   11704, 11705, 11706, 11707, 11708, 11709, 11710, 11711, 11712, 11713, 11714, 11715, 11716],
             1003:[11717,11718,11719,11720,11721,11722,11801, 11802, 11803, 11804, 11805, 11806, 11807, 11808, 11809, 11810,
                  11901, 11902, 11903, 11904, 11905, 11906, 11907, 11908, 11909],
             1004:[11910,11911,11912,11913,12201,12202,12203,12204,12205,12206,111101, 111102, 111103, 111104, 111105, 111106,
                   111107, 111108, 111109, 111110, 111111, 111112, 111113, 111114,111115],
             1005:[111116, 111117, 111118, 111119, 111120, 111121, 111122, 111123, 111124, 111125, 111126, 111127, 111128,
                   111129, 111130, 111131, 111132, 111133, 111134, 111135, 111136, 111137, 111138, 111139,111140],
             2001:[11101, 11102, 11103, 11104, 11105, 11106, 11107, 11108, 11109, 11110, 11111, 11112, 11113, 11114,
               100000:[101001,101002,101003]
}'''
# Out:
# 'Category_dict={10000:[11201, 11202, 11203, 11204, 11205, 11206, 11207, 11208,11301, 11302, 11303,11401, 11402, \n               11403, 11404, 11405, 11406, 11407, 11408, 11409,11601,11602,11603,11604, 11605,11606,11607,11608,\n               11609,11610,11611,11612,11613,11614,   11615,   11616,11701, 11702,11703,11704,11705,11706,11707,\n               11708,11709,11710,11711,11712,11713,11714,11715,11716,11717,11718,11719,11720,11721,11722,11801, 11802, 11803, \n               11804, 11805, 11806, 11807, 11808, 11809, 11810,11901, 11902, 11903, 11904, 11905, 11906, 11907, 11908, \n               11909,11910,11911,11912,11913,11101,11102,11103,11104,11105,11106,11107,11108,11109,11110,11111,11112,11113,\n               11114,11115,11116,11117,11118,11119,11120,11121,11122,11123,11124,11125,11126,11127,11128,11129,12101, \n               12102, 12103, 12104,12201, 12202, 12203, 12204, 12205, 12206,11501,11502,11503,11504,11505,11506,11811,11812,11916,\n                     11917,119
# ...

# %%
#lt=[]
#x=45401
#for i in range(0,10):
#    y=x+i
#    lt.append(y)
#lt

# %%
#tempDict={11104:1001}

# %%
#df_ex['Page_Total_Code']=df_ex['itc'].replace(pg_ttl_dict.values(),pg_ttl_dict.keys())

# %%
df_ex['Itc_Names'] = df_ex['itc'].map(valubl_dict['itc'])

# %%
df_ex.reset_index()
# Out:
#            index        hhcode  province  region       psu     itc       v1  \
# 0             25  1.102010e+09         1       2  11020101   11104   2205.0
# 1             26  1.102010e+09         1       2  11020101   11112   1000.0
# 2             27  1.102010e+09         1       2  11020101   11115    100.0
# 3             28  1.102010e+09         1       2  11020101   11117    110.0
# 4             29  1.102010e+09         1       2  11020101   11201    600.0
# ...          ...           ...       ...     ...       ...     ...      ...
# 2694447  3286329  6.113340e+09         2       2  61133402  123107   3000.0
# 2694448  3286330  6.113340e+09         2       2  61133402  123205    500.0
# 2694449  3286331  6.113340e+09         2       2  61133402  123207   2000.0
# 2694450  3286332  6.113340e+09         2       2  61133402  127006   9000.0
# 2694451  3286333  6.113340e+09         2       2  61133402  127007  24000.0
#
# ...

# %%
#pd.DataFrame(df_ex)

# %%
#valubl_dict['itc'].keys()

# %%
#dct_23=[cat2_dict,cat3_dict]
#dct_12=[cat1_dict,cat2_dict]
#dct_123=[dct_12,dct_23]

# %%
#print(yaml.dump(pg_ttl_dict, sort_keys=True, default_flow_style=False))

# %%
#dict3 = {k : [cat3_dict.get(x,x) for x in v] for k,v in cat2_dict.items()}

# %%
#dict_13={k : [dict3.get(x,x) for x in v] for k,v in cat1_dict.items()}

# %%
#dict_13

# %%
#df_ex['Category_Code']=df_ex['itc'].replace(Category_dict.values(),Category_dict.keys())

# %%
#df_ex

# %%
#dict_13[120000]

# %%
#df_ex['Cat3_Code']=df_ex['itc'].replace(cat3_dict.values(),cat3_dict.keys())

# %%
#df_ex['Cat3_Code']=df_ex['Cat3_Code'].replace(pg_ttl_dict.values(),0)

# %%
#df_ex

# %%
#df_ex['Cat2_Code']=df_ex['itc'].replace(cat2_dict.values(),cat2_dict.keys())

# %%
#df_ex['Cat2_Code']=df_ex['Cat2_Code'].replace(pg_ttl_dict.values(),0)

# %%
#df_ex

# %%
#df_ex['Cat1_Code']=df_ex['itc'].replace(cat1_dict.values(),cat1_dict.keys())

# %%
#df_ex['Cat1_Code']=df_ex['Cat1_Code'].replace(pg_ttl_dict.values(),0)

# %%
#df_ex

# %%
#cols=['Cat3_Code','Cat2_Code','Category_Code']
#df_ex[cols]=df_ex[cols].replace(0,'')

# %%
df_ex
# Out:
#                hhcode  province  region       psu     itc       v1  v2  v3  \
# 25       1.102010e+09         1       2  11020101   11104   2205.0 NaN NaN
# 26       1.102010e+09         1       2  11020101   11112   1000.0 NaN NaN
# 27       1.102010e+09         1       2  11020101   11115    100.0 NaN NaN
# 28       1.102010e+09         1       2  11020101   11117    110.0 NaN NaN
# 29       1.102010e+09         1       2  11020101   11201    600.0 NaN NaN
# ...               ...       ...     ...       ...     ...      ...  ..  ..
# 3286329  6.113340e+09         2       2  61133402  123107   3000.0 NaN NaN
# 3286330  6.113340e+09         2       2  61133402  123205    500.0 NaN NaN
# 3286331  6.113340e+09         2       2  61133402  123207   2000.0 NaN NaN
# 3286332  6.113340e+09         2       2  61133402  127006   9000.0 NaN NaN
# 3286333  6.113340e+09         2       2  61133402  127007  24000.0 NaN NaN
#
#          v4                                          Itc_Names
# ...

# %%
df_ex.dtypes
# Out:
# hhcode       float64
# province        int8
# region          int8
# psu            int32
# itc            int32
# v1           float64
# v2           float64
# v3           float64
# v4           float64
# Itc_Names     object
# dtype: object

# %%
df_ex.memory_usage(deep=True)
# Out:
# Index         21555616
# hhcode        21555616
# province       2694452
# region         2694452
# psu           10777808
# itc           10777808
# v1            21555616
# v2            21555616
# v3            21555616
# v4            21555616
# Itc_Names    227656080
# dtype: int64

# %%
df_ex[["hhcode", "v1",'v2','v3','v4']] = df_ex[["hhcode", "v1",'v2','v3','v4']].apply(pd.to_numeric, downcast="float")

# %%
df_ex.memory_usage(deep=True)
# Out:
# Index         21555616
# hhcode        10777808
# province       2694452
# region         2694452
# psu           10777808
# itc           10777808
# v1            10777808
# v2            10777808
# v3            10777808
# v4            10777808
# Itc_Names    227656080
# dtype: int64

# %%
df_ex["Itc_Names"] = df_ex["Itc_Names"].astype("category")

# %%
df_ex.memory_usage(deep=True)
# Out:
# Index        21555616
# hhcode       10777808
# province      2694452
# region        2694452
# psu          10777808
# itc          10777808
# v1           10777808
# v2           10777808
# v3           10777808
# v4           10777808
# Itc_Names     5450507
# dtype: int64

# %%
df_ex_dict=df_ex.to_dict('itc')
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_2328/1683577027.py:1: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   df_ex_dict=df_ex.to_dict('itc')

# %%
len(df_ex_dict)
# Out:
# 2694452

# %%
l3_11=[11100,11200,11300,11400,11600,11700,11800,11900,12100,12200,12300,111100,45200,56200]
cat3=dict.fromkeys(l3_11,[])

# %%
l2=[11000,12000,111000,56000,121000,45000,31000,43000,54000,72000,73000,95000,52000,51000,71000,82000,91000,32000,53000]
cat2=dict.fromkeys(l2,[])

# %%
l1=[10000,110000,50000,120000,20000,40000,30000,70000,80000,60000,90000,100000]
cat1=dict.fromkeys(l1,[])

# %%
#r1 = []
#for r in range(25,3286333):
#    if r in df_ex_dict.keys():
#        print(df_ex_dict[r]['itc'])
        
    #if 11201<=d<=11299:
        #records = []
    #    if d not in r1:
    #        r1.append(d)
    #        cat3.update({11200:r1})

# %%
#df_ex_dict.keys()

# %%
df_ex_dict[25]['itc']
# Out:
# 11104

# %%
def dict_insert(u):
    r1 = []
    for r in range(25,3286333):
        if r in df_ex_dict.keys():
            if (u+1)<=df_ex_dict[r]['itc']<=(u+99):
                if df_ex_dict[r]['itc'] not in r1:
                    r1.append(df_ex_dict[r]['itc'])
                    cat3.update({u:r1})

# %%
f=(11200,11300,11400,11500,11600,11700,11800,11900,12200,111100,11100,12100,45200,56200)
for i in f:
    dict_insert(i)

# %%
cat3
# Out:
# {11100: [11104,
#   11112,
#   11115,
#   11117,
#   11120,
#   11125,
#   11106,
#   11116,
#   11118,
#   11119,
#   11108,
#   11123,
#   11128,
#   11102,
#   11114,
#   11111,
#   11121,
#   11113,
#   11126,
#   11127,
#   11129,
#   11110,
#   11124,
#   11105,
#   11103,
#   11101,
#   11122,
#   11107,
#   11109],
#  11200: [11201, 11206, 11203, 11204, 11205, 11202, 11207, 11208],
#  11300: [11301, 11302, 11303],
#  11400: [11401, 11402, 11407, 11409, 11403, 11408, 11406, 11405, 11404],
#  11600: [11603,
#   11606,
#   11616,
#   11611,
#   11612,
#   11602,
#   11608,
#   11609,
#   11604,
#   11601,
#   11610,
#   11615,
#   11614,
#   11605,
#   11607,
#   11613],
#  11700: [11701,
#   11702,
#   11705,
#   11717,
#   11718,
#   11720,
#   11703,
#   11704,
#   11706,
#   11715,
#   11716,
#   11711,
#   11719,
#   11709,
#   11712,
#   11722,
#   11708,
#   11714,
#   11707,
#   11713,
#   11721,
#   11710],
#  11800: [11801,
#   11805,
#   11806,
#   11807,
#   11811,
# ...

# %%
def cat2_dict(u):
    r1 = []
    for r in range(25,3286333):
        if r in df_ex_dict.keys():
            if (u+1)<=df_ex_dict[r]['itc']<=(u+999):
                if df_ex_dict[r]['itc'] not in r1:
                    r1.append(df_ex_dict[r]['itc'])
                    cat2.update({u:r1})

# %%
f=(11000,12000,111000,56000,121000,45000,31000,43000,54000,72000,73000,95000,52000,51000,71000,82000,91000,32000,53000)
for i in f:
    cat2_dict(i)

# %%
cat2
# Out:
# {11000: [11104,
#   11112,
#   11115,
#   11117,
#   11201,
#   11206,
#   11401,
#   11402,
#   11407,
#   11409,
#   11505,
#   11603,
#   11606,
#   11616,
#   11701,
#   11702,
#   11705,
#   11717,
#   11718,
#   11801,
#   11906,
#   11911,
#   11912,
#   11919,
#   11120,
#   11125,
#   11403,
#   11611,
#   11720,
#   11106,
#   11116,
#   11118,
#   11119,
#   11612,
#   11703,
#   11704,
#   11706,
#   11108,
#   11123,
#   11128,
#   11504,
#   11602,
#   11608,
#   11609,
#   11715,
#   11716,
#   11805,
#   11806,
#   11102,
#   11114,
#   11203,
#   11711,
#   11111,
#   11121,
#   11807,
#   11113,
#   11126,
#   11127,
#   11301,
#   11408,
#   11604,
#   11719,
#   11811,
#   11812,
#   11909,
#   11917,
#   11918,
#   11129,
#   11204,
#   11205,
#   11601,
#   11709,
#   11712,
#   11808,
#   11902,
#   11907,
#   11913,
#   11916,
#   11406,
#   11722,
#   11905,
#   11708,
#   11714,
#   11707,
#   11110,
#   11713,
#   11802,
#   11809,
#   11910,
#   11803,
# ...

# %%
def cat1_dict(u):
    r1 = []
    for r in range(25,3286333):
        if r in df_ex_dict.keys():
            if (u+1)<=df_ex_dict[r]['itc']<=(u+9999):
                if df_ex_dict[r]['itc'] not in r1:
                    r1.append(df_ex_dict[r]['itc'])
                    cat1.update({u:r1})

# %%
f=(10000,110000,50000,120000,20000,40000,30000,70000,80000,60000,90000,100000)
for i in f:
    cat1_dict(i)

# %%
cat1
# Out:
# {10000: [11104,
#   11112,
#   11115,
#   11117,
#   11201,
#   11206,
#   11401,
#   11402,
#   11407,
#   11409,
#   11505,
#   11603,
#   11606,
#   11616,
#   11701,
#   11702,
#   11705,
#   11717,
#   11718,
#   11801,
#   11906,
#   11911,
#   11912,
#   11919,
#   12102,
#   11120,
#   11125,
#   11403,
#   11611,
#   11720,
#   12201,
#   11106,
#   11116,
#   11118,
#   11119,
#   11612,
#   11703,
#   11704,
#   11706,
#   11108,
#   11123,
#   11128,
#   11504,
#   11602,
#   11608,
#   11609,
#   11715,
#   11716,
#   11805,
#   11806,
#   11102,
#   11114,
#   11203,
#   11711,
#   11111,
#   11121,
#   11807,
#   11113,
#   11126,
#   11127,
#   11301,
#   11408,
#   11604,
#   11719,
#   11811,
#   11812,
#   11909,
#   11917,
#   11918,
#   12203,
#   11129,
#   11204,
#   11205,
#   11601,
#   11709,
#   11712,
#   11808,
#   11902,
#   11907,
#   11913,
#   12101,
#   11916,
#   11406,
#   11722,
#   11905,
#   11708,
#   11714,
#   12205,
#   11707,
#   11110,
# ...

# %%
df_ex['Cat3_Code']=df_ex['itc'].replace(cat3.values(),cat3.keys())

# %%
df_ex['Cat3_Code']=df_ex['Cat3_Code'].replace(pg_ttl_dict.values(),0)

# %%
df_ex
# Out:
#                hhcode  province  region       psu     itc       v1  v2  v3  \
# 25       1.102010e+09         1       2  11020101   11104   2205.0 NaN NaN
# 26       1.102010e+09         1       2  11020101   11112   1000.0 NaN NaN
# 27       1.102010e+09         1       2  11020101   11115    100.0 NaN NaN
# 28       1.102010e+09         1       2  11020101   11117    110.0 NaN NaN
# 29       1.102010e+09         1       2  11020101   11201    600.0 NaN NaN
# ...               ...       ...     ...       ...     ...      ...  ..  ..
# 3286329  6.113340e+09         2       2  61133402  123107   3000.0 NaN NaN
# 3286330  6.113340e+09         2       2  61133402  123205    500.0 NaN NaN
# 3286331  6.113340e+09         2       2  61133402  123207   2000.0 NaN NaN
# 3286332  6.113340e+09         2       2  61133402  127006   9000.0 NaN NaN
# 3286333  6.113340e+09         2       2  61133402  127007  24000.0 NaN NaN
#
# ...

# %%
df_ex['Cat2_Code']=df_ex['itc'].replace(cat2.values(),cat2.keys())

# %%
df_ex['Cat2_Code']=df_ex['Cat2_Code'].replace(pg_ttl_dict.values(),0)

# %%
df_ex
# Out:
#                hhcode  province  region       psu     itc       v1  v2  v3  \
# 25       1.102010e+09         1       2  11020101   11104   2205.0 NaN NaN
# 26       1.102010e+09         1       2  11020101   11112   1000.0 NaN NaN
# 27       1.102010e+09         1       2  11020101   11115    100.0 NaN NaN
# 28       1.102010e+09         1       2  11020101   11117    110.0 NaN NaN
# 29       1.102010e+09         1       2  11020101   11201    600.0 NaN NaN
# ...               ...       ...     ...       ...     ...      ...  ..  ..
# 3286329  6.113340e+09         2       2  61133402  123107   3000.0 NaN NaN
# 3286330  6.113340e+09         2       2  61133402  123205    500.0 NaN NaN
# 3286331  6.113340e+09         2       2  61133402  123207   2000.0 NaN NaN
# 3286332  6.113340e+09         2       2  61133402  127006   9000.0 NaN NaN
# 3286333  6.113340e+09         2       2  61133402  127007  24000.0 NaN NaN
#
# ...

# %%
df_ex['Cat1_Code']=df_ex['itc'].replace(cat1.values(),cat1.keys())

# %%
df_ex
# Out:
#                hhcode  province  region       psu     itc       v1  v2  v3  \
# 25       1.102010e+09         1       2  11020101   11104   2205.0 NaN NaN
# 26       1.102010e+09         1       2  11020101   11112   1000.0 NaN NaN
# 27       1.102010e+09         1       2  11020101   11115    100.0 NaN NaN
# 28       1.102010e+09         1       2  11020101   11117    110.0 NaN NaN
# 29       1.102010e+09         1       2  11020101   11201    600.0 NaN NaN
# ...               ...       ...     ...       ...     ...      ...  ..  ..
# 3286329  6.113340e+09         2       2  61133402  123107   3000.0 NaN NaN
# 3286330  6.113340e+09         2       2  61133402  123205    500.0 NaN NaN
# 3286331  6.113340e+09         2       2  61133402  123207   2000.0 NaN NaN
# 3286332  6.113340e+09         2       2  61133402  127006   9000.0 NaN NaN
# 3286333  6.113340e+09         2       2  61133402  127007  24000.0 NaN NaN
#
# ...

# %%
pg_lst=[1001,1002,1003,1004,1005,2001,2002,2003,4000,5001,5002,5003,5004,6000]
pg_total_dict=dict.fromkeys(pg_lst,[])

# %%
r1001=[]
r1002=[]
r1003=[]
r1004=[]
r1005=[]
r2001=[]
r2002=[]
r2003=[]
r4000=[]
r5001=[]
r5002=[]
r5003=[]
r5004=[]
r6000=[]
for r in range(25,3286333):
    if r in df_ex_dict.keys():
        if 11201<=df_ex_dict[r]['itc']<=11299 or 11301<=df_ex_dict[r]['itc']<=11399 or 11401<=df_ex_dict[r]['itc']<=11499 or 11601<=df_ex_dict[r]['itc']<=11604:
            if df_ex_dict[r]['itc'] not in r1001:
                r1001.append(df_ex_dict[r]['itc'])
                pg_total_dict.update({1001:r1001})
        elif 11605<=df_ex_dict[r]['itc']<=11699 or 11701<=df_ex_dict[r]['itc']<=11716:
            if df_ex_dict[r]['itc'] not in r1002:
                r1002.append(df_ex_dict[r]['itc'])
                pg_total_dict.update({1002:r1002})
        elif 11717<=df_ex_dict[r]['itc']<=11799 or 11801<=df_ex_dict[r]['itc']<=11810 or 11901<=df_ex_dict[r]['itc']<=11909:
            if df_ex_dict[r]['itc'] not in r1003:
                r1003.append(df_ex_dict[r]['itc'])
                pg_total_dict.update({1003:r1003})
        elif 11910<=df_ex_dict[r]['itc']<=11913 or 12201<=df_ex_dict[r]['itc']<=12999 or 111101<=df_ex_dict[r]['itc']<=111115:
            if df_ex_dict[r]['itc'] not in r1004:
                r1004.append(df_ex_dict[r]['itc'])
                pg_total_dict.update({1004:r1004})
        elif 111116<=df_ex_dict[r]['itc']<=111199:
            if df_ex_dict[r]['itc'] not in r1005:
                r1005.append(df_ex_dict[r]['itc'])
                pg_total_dict.update({1005:r1005})
        elif 11101<=df_ex_dict[r]['itc']<=11124:
            if df_ex_dict[r]['itc'] not in r2001:
                r2001.append(df_ex_dict[r]['itc'])
                pg_total_dict.update({2001:r2001})
        elif 11125<=df_ex_dict[r]['itc']<=11199 or 11501<=df_ex_dict[r]['itc']<=11599 or 11811<=df_ex_dict[r]['itc']<=11899 or 11916<=df_ex_dict[r]['itc']<=11999 or 12101<=df_ex_dict[r]['itc']<=12199 or 56101<=df_ex_dict[r]['itc']<=56105:
            if df_ex_dict[r]['itc'] not in r2002:
                r2002.append(df_ex_dict[r]['itc'])
                pg_total_dict.update({2002:r2002})
        elif 56106<=df_ex_dict[r]['itc']<=56199 or 121101<=df_ex_dict[r]['itc']<=121999:
            if df_ex_dict[r]['itc'] not in r2003:
                r2003.append(df_ex_dict[r]['itc'])
                pg_total_dict.update({2003:r2003})
        elif 22001<=df_ex_dict[r]['itc']<=22999 or 44101<=df_ex_dict[r]['itc']<=44999 or 45201<=df_ex_dict[r]['itc']<=45299 or 45101<=df_ex_dict[r]['itc']<=45199 or 45301<=df_ex_dict[r]['itc']<=45699:
            if df_ex_dict[r]['itc'] not in r4000:
                r4000.append(df_ex_dict[r]['itc'])
                pg_total_dict.update({4000:r4000})
        elif 31001<=df_ex_dict[r]['itc']<=32999 or 41101<=df_ex_dict[r]['itc']<=43299:
            if df_ex_dict[r]['itc'] not in r5001:
                r5001.append(df_ex_dict[r]['itc'])
                pg_total_dict.update({5001:r5001})
        elif 56201<=df_ex_dict[r]['itc']<=56299 or 54101<=df_ex_dict[r]['itc']<=54103 or 72101<=df_ex_dict[r]['itc']<=73999 or 11916<=df_ex_dict[r]['itc']<=11999 or 81001<=df_ex_dict[r]['itc']<=81999 or 83001<=df_ex_dict[r]['itc']<=83999:
            if df_ex_dict[r]['itc'] not in r5002:
                r5002.append(df_ex_dict[r]['itc'])
                pg_total_dict.update({5002:r5002})
        elif 61101<=df_ex_dict[r]['itc']<=63999 or 93101<=df_ex_dict[r]['itc']<=95299 or 101001<=df_ex_dict[r]['itc']<=109999 or 95101<=df_ex_dict[r]['itc']<=95399 or 95401<=df_ex_dict[r]['itc']<=95499:
            if df_ex_dict[r]['itc'] not in r5003:
                r5003.append(df_ex_dict[r]['itc'])
                pg_total_dict.update({5003:r5003})
        elif 112001<=df_ex_dict[r]['itc']<=112999 or 53101<=df_ex_dict[r]['itc']<=53102 or 123104<=df_ex_dict[r]['itc']<=127999 or df_ex_dict[r]['itc']==123101:
            if df_ex_dict[r]['itc'] not in r5004:
                r5004.append(df_ex_dict[r]['itc'])
                pg_total_dict.update({5004:r5004})
        elif 52201<=df_ex_dict[r]['itc']<=52999 or 54104<=df_ex_dict[r]['itc']<=54199 or 51101<=df_ex_dict[r]['itc']<=51999 or 53103<=df_ex_dict[r]['itc']<=53999 or 55101<=df_ex_dict[r]['itc']<=55999 or 71101<=df_ex_dict[r]['itc']<=71999 or 82101<=df_ex_dict[r]['itc']<=82999 or 91101<=df_ex_dict[r]['itc']<=91999 or 123102<=df_ex_dict[r]['itc']<=123103:
            if df_ex_dict[r]['itc'] not in r6000:
                r6000.append(df_ex_dict[r]['itc'])
                pg_total_dict.update({6000:r6000})
        #else:
            #print("Every key has been accounted for")

# %%
pg_total_dict
# Out:
# {1001: [11201,
#   11206,
#   11401,
#   11402,
#   11407,
#   11409,
#   11603,
#   11403,
#   11602,
#   11203,
#   11301,
#   11408,
#   11604,
#   11204,
#   11205,
#   11601,
#   11406,
#   11202,
#   11405,
#   11207,
#   11404,
#   11302,
#   11208,
#   11303],
#  1002: [11606,
#   11616,
#   11701,
#   11702,
#   11705,
#   11611,
#   11612,
#   11703,
#   11704,
#   11706,
#   11608,
#   11609,
#   11715,
#   11716,
#   11711,
#   11709,
#   11712,
#   11708,
#   11714,
#   11707,
#   11713,
#   11610,
#   11615,
#   11614,
#   11605,
#   11607,
#   11710,
#   11613],
#  1003: [11717,
#   11718,
#   11801,
#   11906,
#   11720,
#   11805,
#   11806,
#   11807,
#   11719,
#   11909,
#   11808,
#   11902,
#   11907,
#   11722,
#   11905,
#   11802,
#   11809,
#   11803,
#   11810,
#   11901,
#   11908,
#   11804,
#   11721,
#   11904,
#   11903],
#  1004: [11911,
#   11912,
#   12201,
#   111101,
#   111103,
#   111105,
#   111106,
#   111108,
#   111112,
#   12203,
# ...

# %%
total=[1000,2000,4000,5000,6000]
total_part=dict.fromkeys(total,[])

# %%
r1000=[]
r2000=[]
r4000=[]
r5000=[]
r6000=[]
for r in range(25,3286333):
    if r in df_ex_dict.keys():
        if 11201<=df_ex_dict[r]['itc']<=11299 or 11301<=df_ex_dict[r]['itc']<=11399 or 11401<=df_ex_dict[r]['itc']<=11499 or 11601<=df_ex_dict[r]['itc']<=11604 or 11605<=df_ex_dict[r]['itc']<=11699 or 11701<=df_ex_dict[r]['itc']<=11716 or 11717<=df_ex_dict[r]['itc']<=11799 or 11801<=df_ex_dict[r]['itc']<=11810 or 11901<=df_ex_dict[r]['itc']<=11909 or 11910<=df_ex_dict[r]['itc']<=11913 or 12201<=df_ex_dict[r]['itc']<=12999 or 111101<=df_ex_dict[r]['itc']<=111115 or 111116<=df_ex_dict[r]['itc']<=111199:
            if df_ex_dict[r]['itc'] not in r1000:
                r1000.append(df_ex_dict[r]['itc'])
                total_part.update({1000:r1000})
        elif 11101<=df_ex_dict[r]['itc']<=11124 or 11125<=df_ex_dict[r]['itc']<=11199 or 11501<=df_ex_dict[r]['itc']<=11599 or 11811<=df_ex_dict[r]['itc']<=11899 or 11916<=df_ex_dict[r]['itc']<=11999 or 12101<=df_ex_dict[r]['itc']<=12199 or 56101<=df_ex_dict[r]['itc']<=56105 or 56106<=df_ex_dict[r]['itc']<=56199 or 121101<=df_ex_dict[r]['itc']<=121999:
            if df_ex_dict[r]['itc'] not in r2000:
                r2000.append(df_ex_dict[r]['itc'])
                total_part.update({2000:r2000})
        elif 22001<=df_ex_dict[r]['itc']<=22999 or 44101<=df_ex_dict[r]['itc']<=44999 or 45201<=df_ex_dict[r]['itc']<=45299 or 45101<=df_ex_dict[r]['itc']<=45199 or 45301<=df_ex_dict[r]['itc']<=45699:
            if df_ex_dict[r]['itc'] not in r4000:
                r4000.append(df_ex_dict[r]['itc'])
                total_part.update({4000:r4000})
        elif 31001<=df_ex_dict[r]['itc']<=32999 or 41101<=df_ex_dict[r]['itc']<=43299 or 56201<=df_ex_dict[r]['itc']<=56299 or 54101<=df_ex_dict[r]['itc']<=54103 or 72101<=df_ex_dict[r]['itc']<=73999 or 11916<=df_ex_dict[r]['itc']<=11999 or 81001<=df_ex_dict[r]['itc']<=81999 or 83001<=df_ex_dict[r]['itc']<=83999 or 61101<=df_ex_dict[r]['itc']<=63999 or 93101<=df_ex_dict[r]['itc']<=95299 or 101001<=df_ex_dict[r]['itc']<=109999 or 95101<=df_ex_dict[r]['itc']<=95399 or 112001<=df_ex_dict[r]['itc']<=112999 or 53101<=df_ex_dict[r]['itc']<=53102 or 123104<=df_ex_dict[r]['itc']<=127999 or df_ex_dict[r]['itc']==123101 or 95401<=df_ex_dict[r]['itc']<=95499:
            if df_ex_dict[r]['itc'] not in r5000:
                r5000.append(df_ex_dict[r]['itc'])
                total_part.update({5000:r5000})
        elif 52201<=df_ex_dict[r]['itc']<=52999 or 54104<=df_ex_dict[r]['itc']<=54199 or 51101<=df_ex_dict[r]['itc']<=51999 or 53103<=df_ex_dict[r]['itc']<=53999 or 55101<=df_ex_dict[r]['itc']<=55999 or 71101<=df_ex_dict[r]['itc']<=71999 or 82101<=df_ex_dict[r]['itc']<=82999 or 91101<=df_ex_dict[r]['itc']<=91999 or 123102<=df_ex_dict[r]['itc']<=123103:
            if df_ex_dict[r]['itc'] not in r6000:
                r6000.append(df_ex_dict[r]['itc'])
                total_part.update({6000:r6000})

# %%
total_part
# Out:
# {1000: [11201,
#   11206,
#   11401,
#   11402,
#   11407,
#   11409,
#   11603,
#   11606,
#   11616,
#   11701,
#   11702,
#   11705,
#   11717,
#   11718,
#   11801,
#   11906,
#   11911,
#   11912,
#   11403,
#   11611,
#   11720,
#   12201,
#   111129,
#   111132,
#   11612,
#   11703,
#   11704,
#   11706,
#   11602,
#   11608,
#   11609,
#   11715,
#   11716,
#   11805,
#   11806,
#   11203,
#   11711,
#   111131,
#   111101,
#   111103,
#   111105,
#   111106,
#   111108,
#   111112,
#   11807,
#   11301,
#   11408,
#   11604,
#   11719,
#   11909,
#   12203,
#   111102,
#   111104,
#   111110,
#   111115,
#   111117,
#   111118,
#   111122,
#   111125,
#   111127,
#   111133,
#   11204,
#   11205,
#   11601,
#   11709,
#   11712,
#   11808,
#   11902,
#   11907,
#   11913,
#   11406,
#   11722,
#   11905,
#   11708,
#   11714,
#   12205,
#   11707,
#   11713,
#   11802,
#   11809,
#   11910,
#   11803,
#   111107,
#   111136,
#   111128,
#   111111,
#   111134,
#   12202,
# ...

# %%
df_ex['Page_Code']=df_ex['itc'].replace(pg_total_dict.values(),pg_total_dict.keys())

# %%
df_ex['Total Page Code']=df_ex['itc'].replace(total_part.values(),total_part.keys())

# %%
df_ex
# Out:
#                hhcode  province  region       psu     itc       v1  v2  v3  \
# 25       1.102010e+09         1       2  11020101   11104   2205.0 NaN NaN
# 26       1.102010e+09         1       2  11020101   11112   1000.0 NaN NaN
# 27       1.102010e+09         1       2  11020101   11115    100.0 NaN NaN
# 28       1.102010e+09         1       2  11020101   11117    110.0 NaN NaN
# 29       1.102010e+09         1       2  11020101   11201    600.0 NaN NaN
# ...               ...       ...     ...       ...     ...      ...  ..  ..
# 3286329  6.113340e+09         2       2  61133402  123107   3000.0 NaN NaN
# 3286330  6.113340e+09         2       2  61133402  123205    500.0 NaN NaN
# 3286331  6.113340e+09         2       2  61133402  123207   2000.0 NaN NaN
# 3286332  6.113340e+09         2       2  61133402  127006   9000.0 NaN NaN
# 3286333  6.113340e+09         2       2  61133402  127007  24000.0 NaN NaN
#
# ...

# %%
df_ex['Cat3_Code']=df_ex['Cat3_Code'].replace(pg_ttl_dict.values(),0)
#pg_ttl_dict.values()

# %%
df_ex['Cat2_Code']=df_ex['Cat2_Code'].replace(pg_ttl_dict.values(),0)

# %%
df_ex['Cat1_Code']=df_ex['Cat1_Code'].replace(pg_ttl_dict.values(),0)

# %%
df_slct=df_ex[['hhcode','itc','v1','Cat3_Code','Cat2_Code','Cat1_Code','Page_Code','Total Page Code']]

# %%
df_slct
# Out:
#                hhcode     itc       v1  Cat3_Code  Cat2_Code  Cat1_Code  \
# 25       1.102010e+09   11104   2205.0      11100      11000      10000
# 26       1.102010e+09   11112   1000.0      11100      11000      10000
# 27       1.102010e+09   11115    100.0      11100      11000      10000
# 28       1.102010e+09   11117    110.0      11100      11000      10000
# 29       1.102010e+09   11201    600.0      11200      11000      10000
# ...               ...     ...      ...        ...        ...        ...
# 3286329  6.113340e+09  123107   3000.0          0          0     120000
# 3286330  6.113340e+09  123205    500.0          0          0     120000
# 3286331  6.113340e+09  123207   2000.0          0          0     120000
# 3286332  6.113340e+09  127006   9000.0          0          0     120000
# 3286333  6.113340e+09  127007  24000.0          0          0     120000
#
#          Page_Code  Total Page Code
# 25            2001             2000
# ...

# %%
df1 = pd.DataFrame(df_slct[0:1000000])
#df2 = pd.DataFrame(df_slct[1000001:2000000])
#df3 = pd.DataFrame(df_slct[2000001:3000000])

# %%
number_of_row = 1000000

loop_count = int(len(df1) / number_of_row)

for cycle in range(loop_count):
    df1[cycle*number_of_row:(cycle+1)*number_of_row].to_excel('G:\IDM Downloads\data_in_stata\Stata_4abcde.xlsx'.format(cycle))

# %%
#df1 = pd.DataFrame(df_slct[0:1000000])
#df2 = pd.DataFrame(df_slct[1000001:2000000])
#df3 = pd.DataFrame(df_slct[2000001:3000000])

# %%
#df1.to_excel('Stata_4ae.xlsx', sheet_name='First Sheet')
#df2.to_excel('Stata_4ae.xlsx', sheet_name='Second Sheet')
#df3.to_excel('Stata_4ae.xlsx', sheet_name='Third Sheet')
